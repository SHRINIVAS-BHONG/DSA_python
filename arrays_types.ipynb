# %%
A = [1, 2, 3]
print(A)
# Out:
# [1, 2, 3]

# %%
A.append(5)
A
# Out:
# [1, 2, 3, 5]

# %%
A.pop()
A
# Out:
# [1, 2, 3]

# %%
A.insert(2, 5)
A
# Out:
# [1, 2, 5, 3]

# %%
print(A[2])
A
# Out:
# 5
# [1, 2, 5, 3]

# %%
print(len(A))

if 7 in A:
    print("Found")
else:
    print("Not Found")
# Out:
# 4
# Not Found

# %%
s = "hello"
b = s + 'z'
print(b)
# Out:
# helloz

# %%
print(len(s))
# Out:
# 5
