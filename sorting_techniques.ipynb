# %%
# Bubble Sort
# Time : O(n^2)
# Space: O(1)

A = [-5, 3, 2, 1, -3, 7, 2, 2]

def bubble_sort(arr):
    n = len(arr)
    flag = True
    while flag:
        flag = False
        for i in range(1, n):
            if arr[i-1] > arr[i]:
                arr[i-1], arr[i] = arr[i], arr[i-1]
                flag = True

    return arr

print(bubble_sort(A))
# Out:
# [-5, -3, 1, 2, 2, 2, 3, 7]

# %%
# insertion sort
# Time : O(n^2)
# Space: O(1)

B = [-5, 3, 2, 1, -3, 7, 2, 2]

def insertion_sort(arr):
    n = len(arr)
    for i in range(1,n):
        for j in range(i, 0, -1):
            if arr[j] < arr[j-1]:
                arr[j], arr[j-1] = arr[j-1], arr[j]
            else:
                break
    return arr

print(insertion_sort(B))
# Out:
# [-5, -3, 1, 2, 2, 2, 3, 7]

# %%
# selection sort
# Time : O(n^2)
# Space: O(1)

C = [-5, 3, 2, 1, -3, 7, 2, 2]

def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_index = i
        for j in range(i+1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr

print(selection_sort(C))
# Out:
# [-5, -3, 1, 2, 2, 2, 3, 7]

# %%
# merge sort
# Time : O(n log n)
# Space: O(n)

D = [-5, 3, 2, 1, -3, 7, 2, 2] 


def merge_sort(arr):
    n = len(arr)

    if n == 1:
        return arr
    mid = n // 2
    L = arr[:mid]
    R = arr[mid:]

    L = merge_sort(L)
    R = merge_sort(R)
    l, r = 0, 0
    L_len = len(L)
    R_len = len(R)

    sorted_arr = [0] * n
    i = 0

    while l < L_len and r < R_len:
        if L[l] < R[r]:
            sorted_arr[i] = L[l]
            l += 1
        else:
            sorted_arr[i] = R[r]
            r += 1
        i += 1

    while l < L_len:
        sorted_arr[i] = L[l]
        l += 1
        i += 1
    
    while r < R_len:
        sorted_arr[i] = R[r]
        r += 1
        i += 1
    
    return sorted_arr

merge_sort(D)
# Out:
# [-5, -3, 1, 2, 2, 2, 3, 7]

# %%
# Quick Sort
# Time : O(n log n) on average, O(n^2) worst case
# space: O(n)

E = [-5, 3, 2, 1, -3, 7, 2, 2]

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    
    pivot = arr[-1]

    L = [x for x in arr[:-1] if x <= pivot]
    R = [x for x in arr[:-1] if x > pivot]

    L = quick_sort(L)
    R = quick_sort(R)

    return L + [pivot] + R

print(quick_sort(E))
# Out:
# [-5, -3, 1, 2, 2, 2, 3, 7]

# %%
# COUNTING SORT(this used when array is positive integers and range is small)
# Time : O(n + k) where k is the range of input
# k is the maximum element in the array
# space: O(1)

def counting_sort(arr):
    if not arr:
        return arr

    max_val = max(arr)
    count = [0] * (max_val + 1)

    for num in arr:
        count[num] += 1

    sorted_arr = []
    for i in range(len(count)):
        sorted_arr.extend([i] * count[i])

    return sorted_arr

E = [4, 2, 2, 8, 3, 3, 1]
print(counting_sort(E))
# Out:
# [1, 2, 2, 3, 3, 4, 8]

# %%
# what we usually do in practice
# time complexity: O(n log n) from usig time sort

# %%
G = [-5, 3, 2, 1, -3, 7, 2, 2]
G.sort()
G
# Out:
# [-5, -3, 1, 2, 2, 2, 3, 7]

# %%
H = [-5, 3, 2, 1, -3, 7, 2, 2]

sorted_H = sorted(H)
sorted_H
# Out:
# [-5, -3, 1, 2, 2, 2, 3, 7]

# %%
# sort array of tuples

I = [(3, 'apple'), (1, 'banana'), (2, 'cherry'), (1, 'date')]

sorted_I = sorted(I, key=lambda x: x[1], reverse=True)
sorted_I
# Out:
# [(1, 'date'), (2, 'cherry'), (1, 'banana'), (3, 'apple')]
